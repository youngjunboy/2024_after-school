# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('font',family="Malgun Gothic")
df1 = pd.read_csv('범죄장소.csv', encoding='cp949')
df2 = pd.read_csv('범죄지역.csv', encoding='cp949')
df3 = pd.read_csv('범죄시간대_요일.csv', encoding='cp949')
df4 = pd.read_csv('연도별_사이버범죄.csv', encoding='cp949')

# %%
plt.plot(df1['범죄대분류'])
plt.xticks(rotation=45)
# Out:
# (array([-5.,  0.,  5., 10., 15., 20., 25., 30., 35., 40.]),
#  [Text(-5.0, 0, '−5'),
#   Text(0.0, 0, '0'),
#   Text(5.0, 0, '5'),
#   Text(10.0, 0, '10'),
#   Text(15.0, 0, '15'),
#   Text(20.0, 0, '20'),
#   Text(25.0, 0, '25'),
#   Text(30.0, 0, '30'),
#   Text(35.0, 0, '35'),
#   Text(40.0, 0, '40')])
